# %% [markdown]
# # **Praktikum 2**
# Sherly Santiadi (2072025)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import pandas as pd
# save filepath to variable for easier access
path="/content/drive/My Drive/praktikum-ml/WineQT.csv"

# read the data and store data in DataFrame titled wine_data
wine_data=pd.read_csv(path,index_col=0)

# print a summary of the data in Wine data
wine_data.head()
# Out:
# Mounted at /content/drive
#                volatile acidity  citric acid  ...  quality  Id
# fixed acidity                                 ...
# 7.4                        0.70         0.00  ...        5   0
# 7.8                        0.88         0.00  ...        5   1
# 7.8                        0.76         0.04  ...        5   2
# 11.2                       0.28         0.56  ...        6   3
# 7.4                        0.70         0.00  ...        5   4
#
# [5 rows x 12 columns]

# %%
wine_data.shape
# Out:
# (1143, 13)

# %%
import numpy as np
# axis=1 : column
# using drop because it's better to drop what column we don't need instead of adding one by one what column that we need
X = wine_data.drop(['quality'],axis=1)
X.shape
# Out:
# (1143, 12)

# %%
y= wine_data['quality'].values[:,np.newaxis]
y.shape
# Out:
# (1143, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train.shape
# Out:
# (914, 1)

# %%
y_test.shape
# Out:
# (229, 1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1)

# %%
X_train.shape
# Out:
# (685, 1)

# %%
X_val.shape
# Out:
# (229, 1)

# %%
X_test.shape
# Out:
# (229, 1)

# %%
# Plotting Quality of Wine
import matplotlib.pyplot as plt
import matplotlib.lines as lines
import seaborn as sns

plt.figure(figsize = (6,4))
sns.countplot(wine_data['quality'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Plotting the highest correlated pairs from wine data
sns.scatterplot(data=wine_data, x='density', y='alcohol', hue='quality')
plt.show()

# %%
x=wine_data.drop('quality', axis=1)
y=wine_data['quality']
x.hist(figsize=(10,10),  color = "red")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f66e3ee7f90>,
# ...
#       dtype=object)

# %%
sns.displot(wine_data['quality'],kde = True);

# %%
# %matplotlib inline
wine_data.plot(kind='scatter',x='quality',y='alcohol')
